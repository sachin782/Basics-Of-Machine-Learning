# %% [markdown]
# # 7: DATA CLASSIFICATION

# %% [markdown]
# Decision Tree Classifier for iris data set.
#
# Here we are splitting data into 70% training and 30% test datasets randomly and then applying decision tree classifier.

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import pandas as pd
iris = load_iris()
X = iris.data 
Y = iris.target
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3)
clf = tree.DecisionTreeClassifier(criterion = "entropy")
clf = clf.fit(X_train,Y_train)
Y_predict = clf.predict(X_test)
print("Confusion Matrix:\n",confusion_matrix(Y_test, Y_predict))
print ("\nTest Accuracy : ", accuracy_score(Y_test,Y_predict)*100)
feature_imp = pd.Series(clf.feature_importances_,index=iris.feature_names).sort_values(ascending=False)
print("\nFeature Importances:\n",feature_imp)
tree.plot_tree(clf.fit(X_train, Y_train))
print("\n****************     Decision Tree     ***********\n")
plt.show()
# Out:
# Confusion Matrix:
#  [[17  0  0]
#  [ 0 15  2]
#  [ 0  2  9]]
#
# Test Accuracy :  91.11111111111111
#
# Feature Importances:
#  petal width (cm)     0.898972
# sepal width (cm)     0.072508
# petal length (cm)    0.023368
# sepal length (cm)    0.005151
# dtype: float64
#
# ****************     Decision Tree     ***********

# %% [markdown]
# Random Forest Classifier for iris data set.
#
# Here we are splitting data into 70% training and 30% test datasets randomly and then applying random forest classifier.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import pandas as pd
iris = load_iris()
X = iris.data 
Y = iris.target
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3)
clf = RandomForestClassifier(n_estimators = 100)
clf = clf.fit(X_train,Y_train)
Y_predict = clf.predict(X_test)
print("Confusion Matrix:\n",confusion_matrix(Y_test, Y_predict))
print ("\nTest Accuracy : ", accuracy_score(Y_test,Y_predict)*100)
feature_imp = pd.Series(clf.feature_importances_,index=iris.feature_names).sort_values(ascending=False)
print("\nFeature Importances:\n",feature_imp)
# Out:
# Confusion Matrix:
#  [[18  0  0]
#  [ 0 11  0]
#  [ 0  3 13]]
#
# Test Accuracy :  93.33333333333333
#
# Feature Importances:
#  petal width (cm)     0.475324
# petal length (cm)    0.395885
# sepal length (cm)    0.098169
# sepal width (cm)     0.030623
# dtype: float64

# %% [markdown]
# Submitted By:
# Sachin Rawat
# RA1912039010003
# Big Data Analytics
